# %% [markdown]
# Вы работаете секретарем и вам постоянно приходят различные документы. Вы должны быть очень внимательны, чтобы не потерять ни один документ. Каталог документов хранится в следующем виде:
#
#
# documents = [
#     {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
#     {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
#     {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
# ]
# Перечень полок, на которых находятся документы хранится в следующем виде:
#
# directories = {
#     '1': ['2207 876234', '11-2'],
#     '2': ['10006'],
#     '3': []
# }
#
# Необходимо реализовать пользовательские команды (внимание! это не название функций, которые должны быть выразительными, а команды, которые вводит пользователь, чтобы получить необходимый результат):
#
# p – people – команда, которая спросит номер документа и выведет имя человека, которому он принадлежит;
# s – shelf – команда, которая спросит номер документа и выведет номер полки, на которой он находится
# Правильно обработайте ситуации, когда пользователь будет вводить несуществующий документ.
# l – list – команда, которая выведет список всех документов в формате
# passport "2207 876234" "Василий Гупкин"
# as – add shelf – команда, которая спросит номер новой полки и добавит ее в перечень. Предусмотрите случай, когда пользователь добавляет полку, которая уже существует.
# d – delete – команда, которая спросит номер документа и удалит его из каталога и из перечня полок. Предусмотрите сценарий, когда пользователь вводит несуществующий документ;
# m – move – команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую. Корректно обработайте кейсы, когда пользователь пытается переместить несуществующий документ или переместить документ на несуществующую полку;
# a – add – команда, которая добавит новый документ в каталог и в перечень полок, спросив его номер, тип, имя владельца и номер полки, на котором он будет храниться. Корректно обработайте ситуацию, когда пользователь будет пытаться добавить документ на несуществующую полку.

# %%
documents = [
    {'type': 'passport', 'number': '2207 876234', 'name': 'Василий Гупкин'},
    {'type': 'invoice', 'number': '11-2', 'name': 'Геннадий Покемонов'},
    {'type': 'insurance', 'number': '10006', 'name': 'Аристарх Павлов'}
]

directories = {
    '1': ['2207 876234', '11-2'],
    '2': ['10006'],
    '3': []
}

def people():# people -обращение к документам сделано
    user_input=input('введите номер документа ')
    for document in documents:
        if document.get('number')==user_input:
            fio=document.get('name')
            break
        else:
            fio='Нет такого документа'
    return print(fio)


def shelf():# shelf -обращение к полкам сделано
    user_input2=input('введите номер документа ')
    shelf_number='Нет документа'
    for directorie,number in directories.items():
        for doc in number:
            if user_input2==doc:
                shelf_number=directorie
        break
    return print(shelf_number) 

def delete():#delete -удаление документа, с проверкой на ее наличие сделано
    user_input3=input('введите номер документа для удаления ')
    text='Нет такого документа'
    for document in documents:
        if document.get('number')==user_input3:
            text='документ удален'
            documents.remove(document)
            for directorie,number in directories.items():
                for doc in number:
                    if user_input3==doc:
                        number.remove(doc)
    return print(text)


def doclist():#list -вывод всех документов в формате сделано
    for doc in documents:
        print(f'{doc["type"]} \"{doc["number"]}\" \'{doc["name"]}\'')
    return

def add_shelf():# add_shelf -добавление новой полки, с проверкой на ее наличие сделано
    user_input3=input('введите номер новой полки ')
    if user_input3 in directories:
            print('полка уже есть')
    else:
        directories[user_input3]=[]
        print(f'полка {user_input3} добавлена')
    return
         
def add(): #add -Добавление всего
    doc_type = input('Введите тип документа: ')
    doc_number = input('Введите номер нового документа: ')   
    shelf_num = input('Введите номер полки: ')
    doc_name = input('Введите имя владельца: ')
#добавление полки
    if shelf_num not in directories.keys():
        print('нет введенной полки, есть полки:')
        for key in directories:
            print(key)
        return 
    for doc in directories.items():
        if doc[0] == shelf_num:
               doc[1].append(doc_number)          
    print(directories)
#добавление документа
    documents.append({'type': doc_type, 'number': doc_number, 'name': doc_name})
    print(documents)
     

def move():#move -команда, которая спросит номер документа и целевую полку и переместит его с текущей полки на целевую
    user_input_number=input('Введите номер документа, который необходимо переместить: ')
    user_input_new_shelf=input('Введите номер полки, на которую необходимо переместить документ: ')
    text=' '
    if user_input_new_shelf not in directories.keys():
        print('нет введенной полки')
    else:
        text='нет такого докумета'
        for directorie,number in directories.items():
            for doc in number:
                if user_input_number==doc:
                    if user_input_new_shelf in directories.keys():
                        for shelfs_item in directories.items():
                            for shelfs_item_info in shelfs_item[1]:
                                if user_input_number==shelfs_item_info:
                                    shelfs_item[1].remove(shelfs_item_info)#удаление номера
                        for shelf_item in directories.items():
                            if shelf_item[0]==user_input_new_shelf:
                                shelf_item[1].append(user_input_number)#добавление номера
                                text=' '

    return print(text)

# %%
cmd_list = { 'p':people, 's':shelf, 'l':doclist, 'as':add_shelf, 'd':delete, 'm':move, 'a':add}
command = 'p'
cmd_list.get(command, 'Unknown command')()
# Out:
# введите номер документа 11-2
# Геннадий Покемонов
